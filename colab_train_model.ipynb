# %% [markdown]
# <a href="https://colab.research.google.com/github/ashriva16/4Denoising/blob/develop/colab_train_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone --branch develop --single-branch https://github.com/ashriva16/4Denoising.git
# %cd 4Denoising
# Out:
# Cloning into '4Denoising'...
# remote: Enumerating objects: 448, done.
# remote: Counting objects: 100% (170/170), done.
# remote: Compressing objects: 100% (123/123), done.
# remote: Total 448 (delta 78), reused 91 (delta 44), pack-reused 278 (from 1)
# Receiving objects: 100% (448/448), 72.13 MiB | 36.78 MiB/s, done.
# Resolving deltas: 100% (180/180), done.
# /content/4Denoising/4Denoising/4Denoising

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data_path = "/content/drive/MyDrive/machine_learning/4Denoising/dataset/20220509_182024_data_binned2.hdf5"
out_dir = "/content/drive/MyDrive/machine_learning/4Denoising/results/"

# Run the script with arguments
# !python scripts/train.py --data_file "$data_path" --result_dir "$out_dir"
# Out:
# Traceback (most recent call last):
#   File "/content/4Denoising/4Denoising/4Denoising/scripts/train.py", line 10, in <module>
#     import core.models as models
# ModuleNotFoundError: No module named 'core'

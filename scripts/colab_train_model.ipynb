# %% [markdown]
# # Clone the repository

# %%
# !git clone --branch develop --single-branch https://github.com/ashriva16/4Denoising.git
# %cd 4Denoising
# Out:
# Cloning into '4Denoising'...
# remote: Enumerating objects: 454, done.
# remote: Counting objects: 100% (176/176), done.
# remote: Compressing objects: 100% (129/129), done.
# remote: Total 454 (delta 81), reused 92 (delta 44), pack-reused 278 (from 1)
# Receiving objects: 100% (454/454), 72.13 MiB | 7.07 MiB/s, done.
# Resolving deltas: 100% (183/183), done.
# /content/4Denoising

# %% [markdown]
# # Mount google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Install dependencies

# %%
# !pip install -e .
# Out:
# Obtaining file:///content/4Denoising
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 113.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 kB 12.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.7/76.7 kB 8.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.8/59.8 kB 6.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 788.2/788.2 kB 51.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 78.7 MB/s eta 0:00:00
# ...
#   Building editable for mic-hackathon-2025 (pyproject.toml) ... done
#   Created wheel for mic-hackathon-2025: filename=mic_hackathon_2025-0.1.0-0.editable-py3-none-any.whl size=6249 sha256=24408e18c1bdef1196ab55527072149b88b8967855bbff70ef37d87c833002ee
# ...

# %%
import tensorflow as tf
tf.config.list_physical_devices("GPU")

import torch, platform
print("cuda?", torch.cuda.is_available())
print("devices:", torch.cuda.device_count())
# !nvidia-smi
# Out:
# cuda? True
# devices: 1
# Mon Dec 29 18:17:42 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   60C    P8             30W /   70W |       2MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %% [markdown]
# # Define directories path

# %%
data_dir = "/content/drive/MyDrive/machine_learning/4Denoising/dataset"
data_file = "20220509_182024_data_binned2.hdf5"
save_dir = "/content/drive/MyDrive/machine_learning/4Denoising/results"

# %% [markdown]
# # Run Training

# %%
# !python -m scripts.train \
  --dataset.data_dir "$data_dir" \
  --dataset.file "$data_file" \
  --output.save_dir "$save_dir" \
  --train.num_epochs 1 \
  --train.batch_size 1
# Out:
# 2025-12-29 18:15:12.936374: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1767032112.956461     946 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1767032112.962458     946 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1767032112.977357     946 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...
